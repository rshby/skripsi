# %% [markdown]
# ## Mencoba Menghapus Outlier dan Normalisasi

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white", context="talk")
import numpy as np

pd.options.display.max_rows = 500

# %% [markdown]
# ### Import Datasets

# %%
df = pd.read_csv("../Datasets/heart.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df_tr = df.loc[:,["trestbps","age"]]
df_tr
# Out:
#      trestbps  age
# 0         145   63
# 1         130   37
# 2         130   41
# 3         120   56
# 4         120   57
# 5         140   57
# 6         140   56
# 7         120   44
# 8         172   52
# 9         150   57
# 10        140   54
# 11        130   48
# 12        130   49
# 13        110   64
# 14        150   58
# 15        120   50
# 16        120   58
# 17        150   66
# 18        150   43
# 19        140   69
# 20        135   59
# 21        130   44
# 22        140   42
# 23        150   61
# 24        140   40
# 25        160   71
# 26        150   59
# 27        110   51
# 28        140   65
# 29        130   53
# 30        105   41
# 31        120   65
# 32        130   44
# 33        125   54
# 34        125   51
# 35        142   46
# 36        135   54
# 37        150   54
# 38        155   65
# 39        160   65
# 40        140   51
# 41        130   48
# 42        104   45
# 43        130   53
# 44        140   39
# 45        120   52
# ...

# %%
kolom = ["age", "trestbps", "thalach", "oldpeak"]
fig, ax = plt.subplots(nrows=2, ncols=2,constrained_layout=True, figsize=(14, 8))
for col, ax in zip(kolom, ax.flatten()):
    sns.boxplot(df[col], ax=ax)

# %%
fig, ax = plt.subplots(nrows=2, constrained_layout=True, figsize=(8, 6))
fig.suptitle("Distribusi kolom trestbps")
_ = sns.boxplot(x=df["trestbps"], ax=ax[0])
_ = sns.distplot(df["trestbps"], ax=ax[1], bins=30)

# %% [markdown]
# ## Menghapus Outlier pada kolom trestbps

# %%
Q1 = df["trestbps"].quantile(0.25) #membuat Q1
Q3 = df["trestbps"].quantile(0.75) #membuat Q3

IQR = Q3 - Q1 #menghitung IQR
print(f"IQR = {IQR}\nQ1 = {Q1}\nQ3 = {Q3}")
# Out:
# IQR = 20.0
# Q1 = 120.0
# Q3 = 140.0

# %%
df_tr = df_tr[(df_tr["trestbps"]>=Q1-(1.5*IQR)) & (df_tr["trestbps"]<=Q3+(1.5*IQR))] #filter outlier
df_tr.reset_index(inplace=True) #reset index
df_tr.drop("index", axis=1, inplace=True) #hapus kolom index lama
# Out:
# C:\Users\ROG\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_tr
# Out:
#      trestbps  age
# 0         145   63
# 1         130   37
# 2         130   41
# 3         120   56
# 4         120   57
# 5         140   57
# 6         140   56
# 7         120   44
# 8         150   57
# 9         140   54
# 10        130   48
# 11        130   49
# 12        110   64
# 13        150   58
# 14        120   50
# 15        120   58
# 16        150   66
# 17        150   43
# 18        140   69
# 19        135   59
# 20        130   44
# 21        140   42
# 22        150   61
# 23        140   40
# 24        160   71
# 25        150   59
# 26        110   51
# 27        140   65
# 28        130   53
# 29        105   41
# 30        120   65
# 31        130   44
# 32        125   54
# 33        125   51
# 34        142   46
# 35        135   54
# 36        150   54
# 37        155   65
# 38        160   65
# 39        140   51
# 40        130   48
# 41        104   45
# 42        130   53
# 43        140   39
# 44        120   52
# 45        140   44
# ...

# %%
df_tr.describe()
# Out:
#          trestbps         age
# count  294.000000  294.000000
# mean   130.095238   54.217687
# std     15.360884    9.132709
# min     94.000000   29.000000
# 25%    120.000000   47.000000
# 50%    130.000000   55.000000
# 75%    140.000000   61.000000
# max    170.000000   77.000000

# %%
df_tr.agg({"trestbps":["max","mean","min"]})
# Out:
#         trestbps
# max   170.000000
# mean  130.095238
# min    94.000000
